# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayureshnema04/Mayuresh-Nema/blob/main/Practice_seet_Pnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Mayuresh n"  #string
age = 35  #Integer
persentage = 75.12  #float
passed = True #Boolean
college = "BIT"  #string

# %%
python = 85
sql = 90
java = 78
math = 70

# %%
tota = python+sql+java+math

# %%
print(persentage)
# Out:
# 75.12

# %%
if persentage>=75:
  print("Distintion")
elif persentage >=60 and persentage <75:
  print("First class")
# Out:
# Distintion

# %%
marks = [85,90,78,70]

# %%
marks[3]
# Out:
# 70

# %%
marks[2]
# Out:
# 78

# %%
marks[0:2]
# Out:
# [85, 90]

# %%
marks[0:3]
# Out:
# [85, 90, 78]

# %%
marks.append(95)

# %%
marks
# Out:
# [85, 90, 78, 70, 85, 95]

# %%
marks.remove(85)

# %%
marks
# Out:
# [90, 78, 70, 85, 95]

# %%
marks.insert(0,95)

# %%
marks
# Out:
# [95, 90, 78, 70, 85, 95]

# %%
marks.pop()
# Out:
# 95

# %%
marks
# Out:
# [95, 90, 78, 70, 85]
