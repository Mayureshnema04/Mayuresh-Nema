# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayureshnema04/Mayuresh-Nema/blob/main/My_First_Session_jnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Mayuresh n"  #string
age = 35  #Integer
persentage = 75.12  #float
passed = True #Boolean

# %%
marks = [85, 90, 78]
student = {"name": "Mayuresh n", "age": 35}
subjects = {"python", "sql", "java"}

# %%
python = 85
sql = 90
java = 78

# %%
total = python+sql+java

# %%
print(persentage)
# Out:
# 75.12

# %%
python%2
# Out:
# 1

# %%
persentage>70
# Out:
# True

# %%
persentage>=75
# Out:
# True

# %%
if persentage>=75:
  print("Distintion")
elif persentage >=60 and persentage <75:
  print("First class")
# Out:
# Distintion

# %%
name = "Mayuresh n"
college = "abc collage"
course = "python programing"

# %%
name
# Out:
# 'Mayuresh n'

# %%
name[0]
# Out:
# 'M'

# %%
len(name)
# Out:
# 10

# %%
name ="    mayuresh   "

# %%
name
# Out:
# '    mayuresh   '

# %%
name.strip()
# Out:
# 'mayuresh'

# %%
name.upper()
# Out:
# '    MAYURESH   '

# %%
name.lower()
# Out:
# '    mayuresh   '

# %%
name.title()
# Out:
# '    Mayuresh   '

# %%
marks = [85, 90, 78, 80, 72, 60, 65, 62]

# %%
marks[5]
# Out:
# 60

# %%
marks[4]
# Out:
# 72

# %%
marks[0:3]
# Out:
# [85, 90, 78]

# %%
marks[0:4]
# Out:
# [85, 90, 78, 80]

# %%
marks.append(66)

# %%
marks
# Out:
# [85, 90, 78, 80, 72, 60, 65, 62, 66]

# %%
marks.insert(2,73)

# %%
marks
# Out:
# [85, 90, 73, 78, 80, 72, 60, 65, 62, 66]

# %%
marks.remove(65)

# %%
marks
# Out:
# [85, 90, 73, 78, 80, 72, 60, 62, 66]

# %%
marks.pop()
# Out:
# 66

# %%
marks
# Out:
# [85, 90, 73, 78, 80, 72, 60, 62]

# %%
#tupples
#dectoneries
#sets

college_location = (19, 723, 24.25) # tupples are imutable # list are mutable

# %%
college_location
# Out:
# (19, 723, 24.25)

# %%
college_location.append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_487/3994783819.py in <cell line: 0>()
# ----> 1 college_location.append()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#dictionary
student = {"name":"Mayur", "age":35, persentage:71.88}

# %%
student
# Out:
# {'name': 'Mayur', 'age': 35, 75.12: 71.88}

# %%
student["name"]
# Out:
# 'Mayur'

# %%
student["age"]
# Out:
# 35

# %%
student["college"]="ISMT"

# %%
student
# Out:
# {'name': 'Mayur', 'age': 35, 75.12: 71.88, 'college': 'ISMT'}

# %%
del student["college"]

# %%
student
# Out:
# {'name': 'Mayur', 'age': 35, 75.12: 71.88}

# %%
student={"name":"Mayur","age": 35, 75.12: 71.88,"persentage": 71.88,"marks": [85,60,90,70,50,45,30]}

# %%
student
# Out:
# {'name': 'Mayur',
#  'age': 35,
#  75.12: 71.88,
#  'persentage': 71.88,
#  'marks': [85, 60, 90, 70, 50, 45, 30]}

# %%
#setes \
subjects=["English", "python", "java", "sql", 25]

# %%
subjects
# Out:
# ['English', 'python', 'java', 'sql', 25]

# %%
unique_subjects= set(subjects)

# %%
unique_subjects
# Out:
# {25, 'English', 'java', 'python', 'sql'}

# %%
unique_subjects.remove("English")

# %%
unique_subjects
# Out:
# {25, 'java', 'python', 'sql'}
