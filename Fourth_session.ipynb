# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayureshnema04/Mayuresh-Nema/blob/main/Fourth_session.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  result = a+b
  return result

# %%
def substract(a,b):
  result = a-b
  return result

# %%
def mutltification(a,b):
  result = a*b
  return result

# %%
def division(a,b):
  result = a-b
  return result

# %%
print(add(10,5))
print(substract(50,25))
print(mutltification(10,3))
print(division(60,6))
# Out:
# 15
# 25
# 30
# 54

# %%
# %%writefile calculation.py
def add(a,b):
  result = a+b
  return result
def substract(a,b):
  result = a-b
  return result
def mutltification(a,b):
  result = a*b
  return result
def division(a,b):
  result = a/b
  return result
# Out:
# Overwriting calculation.py

# %%
# !ls
# Out:
# calculation.py	__pycache__  sample_data

# %%
add(1,3)
# Out:
# 4

# %%
substract(4,3)
# Out:
# 1

# %%
division(10,2)
# Out:
# 8

# %%
mutltification(2,4)
# Out:
# 8

# %%
import calculation

# %%
calculation.add(5,15)
# Out:
# 20

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pow(3,4)
# Out:
# 81.0

# %%
#random
import random
random.randint(1,10000)
# Out:
# 5218

# %%
import datetime
datetime.date.today()
# Out:
# datetime.date(2026, 9, 2)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 9, 2, 16, 19, 52, 701036)

# %%
from zoneinfo import ZoneInfo
datetime.datetime.now(ZoneInfo("Asia/Kolkata"))
# Out:
# datetime.datetime(2026, 9, 2, 21, 57, 59, 706861, tzinfo=zoneinfo.ZoneInfo(key='Asia/Kolkata'))

# %%
"""pakage file management:
calculation.py
date_utle.py
strint_utle.py
customer.py
empployee.py
product.py
invoice.py
"""
# Out:
# 'pakage file management:\ncalculation.py\ndate_utle.py\nstrint_utle.py\ncustomer.py\nempployee.py\nproduct.py\ninvoice.py\n'

# %%
# !nkdir utlities
# Out:
# /bin/bash: line 1: nkdir: command not found

# %%
# !ls
# Out:
# calculation.py	__pycache__  sample_data

# %%
# %%writefileutlities/calculation.py
# def add(a,b):
#   result = a+b
#   return result
# def substract(a,b):
#   result = a-b
#   return result
# def mutltification(a,b):
#   result = a*b
#   return result
# def division(a,b):
#   result = a/b
#   return result
# Out:
# UsageError: Cell magic `%%writefileutlities/calculation.py` not found.

# %%
# !ls
# Out:
# calculation.py	__pycache__  sample_data

# %%
cd utlities #Change Directoiry
# Out:
# [Errno 2] No such file or directory: 'utlities #Change Directoiry'
# /content

# %%
# !ls
# Out:
# calculation.py	__pycache__  sample_data

# %%
cd .. #going out of directoiry
# Out:
# [Errno 2] No such file or directory: '.. #going out of directoiry'
# /content

# %%
# !ls
# Out:
# calculation.py	__pycache__  sample_data

# %%
"""pandas, Numpy, matplotlib, seaborn"""
# Out:
# 'pandas, Numpy, matplotlib, seaborn'

# %%
# !pip install pandas
